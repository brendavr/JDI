# %%
import pandas as pd 

CA = pd.read_csv('JDI.csv')
Census = pd.read_csv('Census.csv')
# Out:
# /var/folders/2d/rskyyr3x54v7smyxgknvdf8r0000gn/T/ipykernel_3414/598636136.py:4: DtypeWarning: Columns (1,2,3,4,6,8,9,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   CA = pd.read_csv('CA.csv')

# %%
merged_df = CA.merge(Census, on='county', how='left')
merged_df.head(5)
# Out:
#                nameFull bookingNumber bookingDate caseNumber inmateNumber  \
# 0          WILDER AMAYA     fn1002001  2010-02-27        NaN          NaN
# 1            SEAN ADAMS     fn1310380  2020-10-16        NaN          NaN
# 2  ECCLESIASTES PRESLEY     fn1410768  2018-01-17        NaN          NaN
# 3  ECCLESIASTES PRESLEY     fn1410768  2018-01-17        NaN          NaN
# 4     KELLY SHAWN GRIMM     fn1505447  2015-06-11        NaN          NaN
#
#                housing1 housing1a  housing2      housing3 nameLast  ...  \
# 0  Monterey County Jail       NaN       NaN           NaN      NaN  ...
# 1  Monterey County Jail       NaN       NaN           NaN      NaN  ...
# 2  Monterey County Jail       NaN       NaN           NaN      NaN  ...
# 3  Monterey County Jail       NaN       NaN  mj4dp 203         NaN  ...
# 4  Monterey County Jail       NaN       NaN  mj5ew 04b         NaN  ...
#
#   Multi-Race Unemp % Hispanic Unemp %  White Unemp % Male Unemp %  \
# ...

# %%
merged_df.to_csv('CensusJDI.csv', index=False)
